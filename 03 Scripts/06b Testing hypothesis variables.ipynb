# %% [markdown]
# ## contents
# ### 01 import libraries & data
# ### 02

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
path = r'C:\Users\erhil\OneDrive\Career Foundry Program\Immersion Data Analytics Course\A6 - Adv. Analytics & Dashboard Design\Project A6'
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared', 'merged3.csv'), index_col = False)

# %%
df.head()
# Out:
#     ID  Severity  Distance(mi)           City       County State     Timezone  \
# 0  C-2         2      0.433173      Lafayette    Lafayette    LA   US/Central
# 1  C-3         2      0.192266         Denver       Denver    CO  US/Mountain
# 2  C-4         4      0.032112       Whittier  Los Angeles    CA   US/Pacific
# 3  C-5         2      0.996057  Connellsville      Fayette    PA   US/Eastern
# 4  C-6         2      0.747595         Dallas       Dallas    TX   US/Central
#
#   Airport_Code    Weather_Timestamp  Temperature(F)  ...  Precipitation(in)  \
# 0         KLFT  2021-11-12 07:59:00            55.0  ...                0.0
# 1         KBKF  2021-10-12 06:58:00            37.0  ...                0.0
# 2         KFUL  2021-02-10 02:53:00            54.0  ...                0.0
# 3         KLBE  2020-09-24 15:53:00            73.0  ...                0.0
# 4         KDAL  2021-06-08 21:53:00            84.0  ...                0.0
#
# ...

# %%
df.shape
# Out:
# (5153650, 22)

# %%
df.describe()
# Out:
#            Severity  Distance(mi)  Temperature(F)  Visibility(mi)  \
# count  5.153650e+06  5.153650e+06    5.153650e+06    5.153650e+06
# mean   2.258540e+00  1.355767e+00    6.388967e+01    9.450740e+00
# std    6.317709e-01  4.092736e+00    1.784324e+01    2.443852e+00
# min    1.000000e+00  4.657500e-05   -3.700000e+01    0.000000e+00
# 25%    2.000000e+00  1.569342e-01    5.200000e+01    1.000000e+01
# 50%    2.000000e+00  3.725871e-01    6.600000e+01    1.000000e+01
# 75%    2.000000e+00  1.134753e+00    7.700000e+01    1.000000e+01
# max    4.000000e+00  6.877400e+02    1.270000e+02    1.000000e+02
#
#        Precipitation(in)  Zipcode_no_ext  dist_to_weather(mi)  \
# count       5.153650e+06    5.153650e+06         5.153650e+06
# mean        2.764270e-03    5.128146e+04         8.840478e+00
# std         4.926369e-02    2.942521e+04         7.591636e+00
# min         0.000000e+00    1.001000e+03         1.283714e-02
# ...

# %%
# Create a scatterplot for the "distance to weather" and "const_total_minutes" columns in seaborn

sns.lmplot(x = 'dist_to_weather(mi)', y = 'const_total_minutes', data = df)

# %%
df.loc[df['dist_to_weather(mi)'] < 6.7, 'removed'] = 'short distance'

# %%
df.loc[df['dist_to_weather(mi)'] >= 6.7, 'removed'] = 'far distance'

# %%
df.head(1)
# Out:
#     ID  Severity  Distance(mi)       City     County State    Timezone  \
# 0  C-2         2      0.433173  Lafayette  Lafayette    LA  US/Central
#
#   Airport_Code    Weather_Timestamp  Temperature(F)  ...  Weather_Condition  \
# 0         KLFT  2021-11-12 07:59:00            55.0  ...      Mostly Cloudy
#
#      Start_Time_no_ext      End_Time_no_ext Zipcode_no_ext   Airport_Type  \
# 0  2021-11-12 07:59:00  2021-11-12 08:22:30          70501  large_airport
#
#                  Airport_Name  dist_to_weather(mi) project_time_length  \
# 0  Lafayette Regional Airport             1.673991     0 days 00:23:30
#
#   const_total_minutes         removed
# 0                23.5  short distance
#
# [1 rows x 23 columns]

# %%
df['removed'].value_counts(dropna = False)
# Out:
# short distance    2583173
# far distance      2570477
# Name: removed, dtype: int64

# %%
sns.set(style="ticks")
g = sns.catplot(x="const_total_minutes", y="dist_to_weather(mi)", hue="removed", data=df)
